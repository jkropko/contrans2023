# %%
import numpy as np
import pandas as pd
import os
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')
import psycopg2
from sqlalchemy import create_engine

# %%
bills=pd.read_csv('Data/bills.csv')              
congress_members=pd.read_csv('Data/congress_members.csv')  
os_legislators=pd.read_csv('Data/os_legislators.csv')
committee_members=pd.read_csv('Data/committee_members.csv')  
leadership=pd.read_csv('Data/leadership.csv')        
terms=pd.read_csv('Data/terms.csv')
committees=pd.read_csv('Data/committees.csv')         
os_contributions=pd.read_csv('Data/os_contributions.csv')  
votingaffinity=pd.read_csv('Data/votingaffinity.csv')

# %% [markdown]
# # Bills

# %%
bills.columns = [x.lower() for x in bills.columns]
bills.columns = [x.replace('.', '_') for x in bills.columns]
bills.columns
# Out:
# Index(['congress', 'introduceddate', 'number', 'title', 'type', 'url',
#        'latestaction_actiondate', 'latestaction_text', 'policyarea_name',
#        'amendmentnumber', 'latestaction', 'latestaction_actiontime'],
#       dtype='object')

# %%
bills.head(3).T
# Out:
#                                                                          0  \
# congress                                                               118
# introduceddate                                                  2023-10-04
# number                                                               405.0
# title                    A resolution expressing support for the design...
# type                                                                  SRES
# url                      https://api.congress.gov/v3/bill/118/sres/405?...
# latestaction_actiondate                                         2023-10-04
# latestaction_text        Submitted in the Senate, considered, and agree...
# policyarea_name                         Armed Forces and National Security
# amendmentnumber                                                        NaN
# latestaction                                                           NaN
# latestaction_actiontime                                                NaN
#
#                                                                          1  \
# congress                                                               118
# introduceddate                                                  2023-09-29
# number                                                              2998.0
# title                    Land-Grant Research Equity and Accountability Act
# type                                                                     S
# url                      https://api.congress.gov/v3/bill/118/s/2998?fo...
# latestaction_actiondate                                         2023-09-29
# latestaction_text        Read twice and referred to the Committee on Ag...
# policyarea_name                                       Agriculture and Food
# amendmentnumber                                                        NaN
# latestaction                                                           NaN
# latestaction_actiontime                                                NaN
#
#                                                                          2
# congress                                                               118
# introduceddate                                                  2023-09-27
# number                                                               373.0
# title                    A resolution designating the week of September...
# type                                                                  SRES
# url                      https://api.congress.gov/v3/bill/118/sres/373?...
# latestaction_actiondate                                         2023-09-27
# latestaction_text        Submitted in the Senate, considered, and agree...
# policyarea_name                                                        NaN
# amendmentnumber                                                        NaN
# latestaction                                                           NaN
# latestaction_actiontime                                                NaN

# %% [markdown]
# ## congress_members

# %%
congress_members.columns = [x.lower() for x in congress_members.columns]
congress_members.columns = [x.replace('.', '_') for x in congress_members.columns]
congress_members.columns
# Out:
# Index(['bioguideid', 'birthyear', 'currentmember', 'directordername',
#        'firstname', 'honorificname', 'invertedordername', 'lastname',
#        'officialwebsiteurl', 'partyhistory', 'state', 'terms', 'updatedate',
#        'addressinformation_city', 'addressinformation_district',
#        'addressinformation_officeaddress', 'addressinformation_phonenumber',
#        'addressinformation_zipcode', 'cosponsoredlegislation_count',
#        'cosponsoredlegislation_url', 'depiction_attribution',
#        'depiction_imageurl', 'sponsoredlegislation_count',
#        'sponsoredlegislation_url', 'middlename', 'suffixname', 'nickname',
#        'leadership', 'district'],
#       dtype='object')

# %%
congress_members = congress_members.drop(['terms', 'leadership',
                                         'partyhistory'], axis=1)

# %%
congress_members.head(3).T
# Out:
#                                                                                   0  \
# bioguideid                                                                  B000944
# birthyear                                                                      1952
# currentmember                                                                  True
# directordername                                                       Sherrod Brown
# firstname                                                                   Sherrod
# honorificname                                                                   Mr.
# invertedordername                                                    Brown, Sherrod
# lastname                                                                      Brown
# officialwebsiteurl                                    https://www.brown.senate.gov/
# state                                                                          Ohio
# updatedate                                                     2023-04-01T12:42:12Z
# addressinformation_city                                                  Washington
# addressinformation_district                                                      DC
# addressinformation_officeaddress  503 Hart Senate Office Building Washington, DC...
# addressinformation_phonenumber                                       (202) 224-2315
# addressinformation_zipcode                                                    20515
# cosponsoredlegislation_count                                                   7873
# cosponsoredlegislation_url        https://api.congress.gov/v3/member/B000944/cos...
# depiction_attribution             <a href="http://www.senate.gov/artandhistory/h...
# depiction_imageurl                https://www.congress.gov/img/member/b000944_20...
# sponsoredlegislation_count                                                   1389.0
# sponsoredlegislation_url          https://api.congress.gov/v3/member/B000944/spo...
# middlename                                                                      NaN
# suffixname                                                                      NaN
# nickname                                                                        NaN
# district                                                                        NaN
#
#                                                                                   1  \
# bioguideid                                                                  C000127
# birthyear                                                                      1958
# currentmember                                                                  True
# directordername                                                      Maria Cantwell
# firstname                                                                     Maria
# honorificname                                                                   Ms.
# invertedordername                                                   Cantwell, Maria
# lastname                                                                   Cantwell
# officialwebsiteurl                                  https://www.cantwell.senate.gov
# state                                                                    Washington
# updatedate                                                     2023-04-01T12:42:12Z
# addressinformation_city                                                  Washington
# addressinformation_district                                                      DC
# addressinformation_officeaddress  511 Hart Senate Office Building Washington, DC...
# addressinformation_phonenumber                                       (202) 224-3441
# addressinformation_zipcode                                                    20515
# cosponsoredlegislation_count                                                   3923
# cosponsoredlegislation_url        https://api.congress.gov/v3/member/C000127/cos...
# depiction_attribution             <a href="http://www.senate.gov/artandhistory/h...
# depiction_imageurl                https://www.congress.gov/img/member/c000127_20...
# sponsoredlegislation_count                                                    882.0
# sponsoredlegislation_url          https://api.congress.gov/v3/member/C000127/spo...
# middlename                                                                      NaN
# suffixname                                                                      NaN
# nickname                                                                        NaN
# district                                                                        NaN
#
#                                                                                   2
# bioguideid                                                                  C000141
# birthyear                                                                      1943
# currentmember                                                                  True
# directordername                                                  Benjamin L. Cardin
# firstname                                                                       Ben
# honorificname                                                                   Mr.
# invertedordername                                               Cardin, Benjamin L.
# lastname                                                                     Cardin
# officialwebsiteurl                                   https://www.cardin.senate.gov/
# state                                                                      Maryland
# updatedate                                                     2023-04-01T12:42:13Z
# addressinformation_city                                                  Washington
# addressinformation_district                                                      DC
# addressinformation_officeaddress  509 Hart Senate Office Building Washington, DC...
# addressinformation_phonenumber                                       (202) 224-4524
# addressinformation_zipcode                                                    20515
# cosponsoredlegislation_count                                                   6100
# cosponsoredlegislation_url        https://api.congress.gov/v3/member/C000141/cos...
# depiction_attribution             <a href="http://www.senate.gov/artandhistory/h...
# depiction_imageurl                https://www.congress.gov/img/member/c000141_20...
# sponsoredlegislation_count                                                   1265.0
# sponsoredlegislation_url          https://api.congress.gov/v3/member/C000141/spo...
# middlename                                                                      NaN
# suffixname                                                                      NaN
# nickname                                                                        NaN
# district                                                                        NaN

# %% [markdown]
# ## Terms

# %%
terms.columns = [x.lower() for x in terms.columns]
terms.columns = [x.replace('.', '_') for x in terms.columns]
terms.head(3).T
# Out:
#                   0        1        2
# chamber      Senate   Senate   Senate
# congress        107      108      109
# endyear      2003.0   2005.0   2007.0
# membertype  Senator  Senator  Senator
# startyear      2002     2003     2005
# statecode        TX       TX       TX
# statename     Texas    Texas    Texas
# bioguideid  C001056  C001056  C001056
# district        NaN      NaN      NaN

# %% [markdown]
# ## Leadership

# %%
leadership.columns = [x.lower() for x in leadership.columns]
leadership.columns = [x.replace('.', '_') for x in leadership.columns]
leadership.head(3).T
# Out:
#                                       0                          1  \
# congress                            113                        114
# type        Assistant Democratic Leader  Assistant Majority Leader
# bioguideid                      C001056                    C001056
# current                             NaN                        NaN
#
#                         2
# congress              115
# type        Majority Whip
# bioguideid        C001056
# current               NaN

# %% [markdown]
# ## os_legislators

# %%
os_legislators.columns = [x.lower() for x in os_legislators.columns]
os_legislators.columns = [x.replace('.', '_') for x in os_legislators.columns]
os_legislators.head(3).T
# Out:
#                            0                                              1  \
# cid                N00050780                                      N00035774
# firstl          Mary Peltola                                   Dan Sullivan
# lastnam              Peltola                                       Sullivan
# party                      D                                              R
# offic                   AK01                                           AKS1
# gend                       F                                              M
# first_elected           2022                                           2014
# xit_cod                    0                                              0
# commen                   NaN                                            NaN
# phon                     NaN                                   202-224-3004
# fax                      NaN                                            NaN
# w                        NaN                https://www.sullivan.senate.gov
# webform                  NaN  https://www.sullivan.senate.gov/contact/email
# congress_offic           NaN                702 Hart Senate Office Building
# oguide_id                NaN                                        S001198
# votesmart_id             NaN                                            NaN
# feccandid                NaN                                      S4AK00214
# witter_id                NaN                                 SenDanSullivan
# youtube_url              NaN                                            NaN
# facebook_id              NaN                                 SenDanSullivan
# hd                       NaN                                     1964-11-13
#
#                                                                 2
# cid                                                     N00026050
# firstl                                             Lisa Murkowski
# lastnam                                                 Murkowski
# party                                                           R
# offic                                                        AKS2
# gend                                                            F
# first_elected                                                2002
# xit_cod                                                         0
# commen                                                        NaN
# phon                                                 202-224-6665
# fax                                                  202-224-5301
# w                                https://www.murkowski.senate.gov
# webform         https://www.murkowski.senate.gov/public/index....
# congress_offic                    522 Hart Senate Office Building
# oguide_id                                                 M001153
# votesmart_id                                              15841.0
# feccandid                                               S4AK00099
# witter_id                                           LisaMurkowski
# youtube_url                  https://youtube.com/senatormurkowski
# facebook_id                                      SenLisaMurkowski
# hd                                                     1957-05-22

# %%
os_legislators = os_legislators[['cid', 'party', 'oguide_id']]
os_legislators = os_legislators.rename({'oguide_id': 'bioguideid'},
                                      axis=1)
os_legislators
# Out:
#            cid party bioguideid
# 0    N00050780     D        NaN
# 1    N00035774     R    S001198
# 2    N00026050     R    M001153
# 3    N00044245     R    C001054
# 4    N00041295     R    M001212
# ..         ...   ...        ...
# 532  N00032838     D    M001183
# 533  N00009771     R    C001047
# 534  N00049197     R    H001096
# 535  N00006236     R    B001261
# 536  N00029788     R    L000571
#
# [537 rows x 3 columns]

# %%
members = pd.merge(congress_members, os_legislators,
                  on = 'bioguideid',
                  how = 'outer',
                  validate = 'one_to_many',
                  indicator = 'matched')

# %%
members['matched'].value_counts()
# Out:
# matched
# both          506
# left_only      31
# right_only     31
# Name: count, dtype: int64

# %%
members = pd.merge(congress_members, os_legislators,
                  on = 'bioguideid',
                  how = 'inner')

# %% [markdown]
# ## os_contributions

# %%
os_contributions.columns = [x.lower() for x in os_contributions.columns]
os_contributions.columns = [x.replace('.', '_') for x in os_contributions.columns]
os_contributions.head(30)
# Out:
#                                   org_nam   otal    pac   ndiv
# 0                         State of Alaska  19541      0  19541
# 1                 Sonosky, Chambers et al  16050      0  16050
# 2               General Communication Inc  15150   2500  12650
# 3                              Google Inc  14164      0  14164
# 4          University of Alaska/Anchorage  13938      0  13938
# 5                              Swing Left  13400      0  13400
# 6                               Apple Inc  10783      0  10783
# 7   Service Employees International Union  10010   5000   5010
# 8                 National Education Assn  10000  10000      0
# 9                           Sealaska Corp   9950      0   9950
# 10                      Rpm International  66950  10000  56950
# 11                          Goldman Sachs  59500   4000  55500
# 12              Calfee, Halter & Griswold  45300      0  45300
# 13    National Republican Senatorial Cmte  44600  44600      0
# 14                       Trident Seafoods  43550   5600  37950
# 15                     Elliott Management  39100      0  39100
# 16                        General Atomics  37550  12500  25050
# 17                         ConocoPhillips  37425  10000  27425
# 18                       Blackstone Group  36100      0  36100
# 19                             Lynden Inc  30700      0  30700
# 20                         ConocoPhillips  60050  10000  50050
# 21    American Israel Public Affairs Cmte  59500  10000  49500
# 22                       Trident Seafoods  55300   5800  49500
# 23    National Republican Senatorial Cmte  51200  51200      0
# 24                               KKR & Co  48405      0  48405
# 25                         NextEra Energy  36450  10000  26450
# 26              General Communication Inc  34900  10000  24900
# 27                            Exelon Corp  34300  11500  22800
# 28                                 NorPAC  31250      0  31250
# 29                          Capital Group  30700      0  30700

# %% [markdown]
# ## committees

# %%
committees.columns = [x.lower() for x in committees.columns]
committees.columns = [x.replace('.', '_') for x in committees.columns]
committees = committees.drop(['subcommittees'], axis=1)

# %%
committees
# Out:
#     chamber committeetypecode  \
# 0     House             Other
# 1     House          Standing
# 2     House            Select
# 3     House            Select
# 4     House            Select
# ..      ...               ...
# 709  Senate          Standing
# 710  Senate          Standing
# 711  Senate          Standing
# 712  Senate          Standing
# 713  Senate          Standing
#
#                                                   name systemcode  \
# 0                                Bicentenary Committee     hcza00
# 1                            Energy (Ad Hoc) Committee     hhah00
# 2                  U.S. Role in Iranian Arms Committee     hlbz00
# 3     Children, Youth, and Families (Select) Committee     hlcf00
# 4               Select Committee on the Climate Crisis     hlcn00
# ..                                                 ...        ...
# 709  Competitiveness, Capital Formation and Economi...     sssb07
# 710  Advocacy and The Future of Small Business Subc...     sssb08
# 711           Small Business: Family Farm Subcommittee     sssb11
# 712  Entrepreneurship and Special Problems Facing S...     sssb12
# 713                        Veterans' Affairs Committee     ssva00
#
#                                                    url  \
# 0    https://api.congress.gov/v3/committee/house/hc...
# 1    https://api.congress.gov/v3/committee/house/hh...
# 2    https://api.congress.gov/v3/committee/house/hl...
# 3    https://api.congress.gov/v3/committee/house/hl...
# 4    https://api.congress.gov/v3/committee/house/hl...
# ..                                                 ...
# 709  https://api.congress.gov/v3/committee/senate/s...
# 710  https://api.congress.gov/v3/committee/senate/s...
# 711  https://api.congress.gov/v3/committee/senate/s...
# 712  https://api.congress.gov/v3/committee/senate/s...
# 713  https://api.congress.gov/v3/committee/senate/s...
#
#                                        parent_name parent_systemcode  \
# 0                                              NaN               NaN
# 1                                              NaN               NaN
# 2                                              NaN               NaN
# 3                                              NaN               NaN
# 4                                              NaN               NaN
# ..                                             ...               ...
# 709  Small Business and Entrepreneurship Committee            sssb00
# 710  Small Business and Entrepreneurship Committee            sssb00
# 711  Small Business and Entrepreneurship Committee            sssb00
# 712  Small Business and Entrepreneurship Committee            sssb00
# 713                                            NaN               NaN
#
#                                             parent_url
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 709  https://api.congress.gov/v3/committee/senate/s...
# 710  https://api.congress.gov/v3/committee/senate/s...
# 711  https://api.congress.gov/v3/committee/senate/s...
# 712  https://api.congress.gov/v3/committee/senate/s...
# 713                                                NaN
#
# [714 rows x 8 columns]

# %% [markdown]
# ## committee_members

# %%
committee_members.columns = [x.lower() for x in committee_members.columns]
committee_members.columns = [x.replace('.', '_') for x in committee_members.columns]
committee_members.head(30)
# Out:
#    committee_code  rank           title bioguide
# 0            HSII   1.0           Chair  W000821
# 1            HSII   1.0  Ranking Member  G000551
# 2            HSII   2.0             NaN  L000564
# 3            HSII   2.0             NaN  N000179
# 4            HSII   3.0             NaN  W000804
# 5            HSII   3.0             NaN  S001177
# 6            HSII   4.0             NaN  M001177
# 7            HSII   4.0             NaN  H001068
# 8            HSII   5.0             NaN  G000565
# 9            HSII   5.0             NaN  G000574
# 10           HSII   6.0             NaN  G000577
# 11           HSII   6.0             NaN  N000191
# 12           HSII   7.0             NaN  R000600
# 13           HSII   7.0             NaN  L000593
# 14           HSII   8.0             NaN  L000578
# 15           HSII   8.0             NaN  P000618
# 16           HSII   9.0             NaN  W000806
# 17           HSII   9.0             NaN  L000273
# 18           HSII  10.0             NaN  G000582
# 19           HSII  10.0             NaN  S001218
# 20           HSII  11.0             NaN  F000469
# 21           HSII  11.0             NaN  P000619
# 22           HSII  12.0             NaN  S001212
# 23           HSII  12.0             NaN  O000172
# 24           HSII  13.0             NaN  C001114
# 25           HSII  13.0             NaN  M001225
# 26           HSII  14.0             NaN  T000165
# 27           HSII  14.0             NaN  H001094
# 28           HSII  15.0             NaN  C001054
# 29           HSII  15.0             NaN  K000400
