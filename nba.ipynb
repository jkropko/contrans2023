# %%
import numpy as np
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import os
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')

# %%
nba = pd.read_csv('nba.csv', low_memory=False)

# %% [markdown]
# ## Original data

# %%
pd.set_option('display.max_rows', 90)
nba.head(3).T
# Out:
#                                                                               0  \
# Unnamed: 0                                                                    0
# game_id                                                            202202170BRK
# game_date                                                            2022-02-17
# OT                                                                            0
# H_A                                                                           A
# Team_Abbrev                                                                 WAS
# Team_Score                                                                  117
# Team_pace                                                                  94.5
# Team_efg_pct                                                              0.627
# Team_tov_pct                                                               13.5
# Team_orb_pct                                                               22.9
# Team_ft_rate                                                              0.157
# Team_off_rtg                                                              123.8
# Inactives                          Joel Ayayi, Bradley Beal, Kristaps Porzingis
# Opponent_Abbrev                                                             BRK
# Opponent_Score                                                              103
# Opponent_pace                                                              94.5
# Opponent_efg_pct                                                          0.483
# Opponent_tov_pct                                                           13.1
# Opponent_orb_pct                                                           33.3
# Opponent_ft_rate                                                          0.191
# Opponent_off_rtg                                                          109.0
# player                                                            Corey Kispert
# player_id                                                             kispeco01
# starter                                                                       1
# mp                                                                        32:30
# fg                                                                            6
# fga                                                                           9
# fg_pct                                                                    0.667
# fg3                                                                           4
# fg3a                                                                          6
# fg3_pct                                                                   0.667
# ft                                                                            0
# fta                                                                           0
# ft_pct                                                                      0.0
# orb                                                                           0
# drb                                                                           1
# trb                                                                           1
# ast                                                                           1
# stl                                                                           2
# blk                                                                           0
# tov                                                                           2
# pf                                                                            2
# pts                                                                          16
# plus_minus                                                                   13
# did_not_play                                                                  0
# is_inactive                                                                   0
# ts_pct                                                                    0.889
# efg_pct                                                                   0.889
# fg3a_per_fga_pct                                                          0.667
# fta_per_fga_pct                                                             0.0
# orb_pct                                                                     0.0
# drb_pct                                                                     3.3
# trb_pct                                                                     1.8
# ast_pct                                                                     4.0
# stl_pct                                                                     3.1
# blk_pct                                                                     0.0
# tov_pct                                                                    18.2
# usg_pct                                                                    15.6
# off_rtg                                                                     133
# def_rtg                                                                     113
# bpm                                                                         3.1
# season                                                                     2022
# minutes                                                                    32.5
# double_double                                                                 0
# triple_double                                                                 0
# DKP                                                                       23.75
# FDP                                                                        22.7
# SDP                                                                       24.75
# DKP_per_minute                                                0.730769230769231
# FDP_per_minute                                                0.698461538461538
# SDP_per_minute                                                0.761538461538461
# pf_per_minute                                                          0.061538
# ts                                                                          9.0
# last_60_minutes_per_game_starting                                     31.716667
# last_60_minutes_per_game_bench                                        22.017778
# PG%                                                                         1.0
# SG%                                                                        36.0
# SF%                                                                        60.0
# PF%                                                                         4.0
# C%                                                                          0.0
# active_position_minutes                                               46.253586
#
#                                                                               1  \
# Unnamed: 0                                                                    1
# game_id                                                            202202170BRK
# game_date                                                            2022-02-17
# OT                                                                            0
# H_A                                                                           A
# Team_Abbrev                                                                 WAS
# Team_Score                                                                  117
# Team_pace                                                                  94.5
# Team_efg_pct                                                              0.627
# Team_tov_pct                                                               13.5
# Team_orb_pct                                                               22.9
# Team_ft_rate                                                              0.157
# Team_off_rtg                                                              123.8
# Inactives                          Joel Ayayi, Bradley Beal, Kristaps Porzingis
# Opponent_Abbrev                                                             BRK
# Opponent_Score                                                              103
# Opponent_pace                                                              94.5
# Opponent_efg_pct                                                          0.483
# Opponent_tov_pct                                                           13.1
# Opponent_orb_pct                                                           33.3
# Opponent_ft_rate                                                          0.191
# Opponent_off_rtg                                                          109.0
# player                                                               Kyle Kuzma
# player_id                                                             kuzmaky01
# starter                                                                       1
# mp                                                                        30:16
# fg                                                                            2
# fga                                                                           7
# fg_pct                                                                    0.286
# fg3                                                                           0
# fg3a                                                                          3
# fg3_pct                                                                     0.0
# ft                                                                            1
# fta                                                                           1
# ft_pct                                                                      1.0
# orb                                                                           0
# drb                                                                           7
# trb                                                                           7
# ast                                                                           5
# stl                                                                           1
# blk                                                                           0
# tov                                                                           7
# pf                                                                            3
# pts                                                                           5
# plus_minus                                                                   10
# did_not_play                                                                  0
# is_inactive                                                                   0
# ts_pct                                                                    0.336
# efg_pct                                                                   0.286
# fg3a_per_fga_pct                                                          0.429
# fta_per_fga_pct                                                           0.143
# orb_pct                                                                     0.0
# drb_pct                                                                    24.7
# trb_pct                                                                    13.9
# ast_pct                                                                    18.5
# stl_pct                                                                     1.7
# blk_pct                                                                     0.0
# tov_pct                                                                    48.5
# usg_pct                                                                    22.0
# off_rtg                                                                      55
# def_rtg                                                                     107
# bpm                                                                       -15.5
# season                                                                     2022
# minutes                                                               30.266667
# double_double                                                                 0
# triple_double                                                                 0
# DKP                                                                       19.75
# FDP                                                                        16.9
# SDP                                                                       17.25
# DKP_per_minute                                                0.652533039647577
# FDP_per_minute                                                0.558370044052863
# SDP_per_minute                                                0.569933920704846
# pf_per_minute                                                          0.099119
# ts                                                                         7.44
# last_60_minutes_per_game_starting                                        34.324
# last_60_minutes_per_game_bench                                        18.475954
# PG%                                                                         0.0
# SG%                                                                         0.0
# SF%                                                                         4.0
# PF%                                                                        85.0
# C%                                                                         11.0
# active_position_minutes                                                52.15259
#
#                                                                               2
# Unnamed: 0                                                                    2
# game_id                                                            202202170BRK
# game_date                                                            2022-02-17
# OT                                                                            0
# H_A                                                                           A
# Team_Abbrev                                                                 WAS
# Team_Score                                                                  117
# Team_pace                                                                  94.5
# Team_efg_pct                                                              0.627
# Team_tov_pct                                                               13.5
# Team_orb_pct                                                               22.9
# Team_ft_rate                                                              0.157
# Team_off_rtg                                                              123.8
# Inactives                          Joel Ayayi, Bradley Beal, Kristaps Porzingis
# Opponent_Abbrev                                                             BRK
# Opponent_Score                                                              103
# Opponent_pace                                                              94.5
# Opponent_efg_pct                                                          0.483
# Opponent_tov_pct                                                           13.1
# Opponent_orb_pct                                                           33.3
# Opponent_ft_rate                                                          0.191
# Opponent_off_rtg                                                          109.0
# player                                                 Kentavious Caldwell-Pope
# player_id                                                             caldwke01
# starter                                                                       1
# mp                                                                        25:26
# fg                                                                            3
# fga                                                                           7
# fg_pct                                                                    0.429
# fg3                                                                           1
# fg3a                                                                          3
# fg3_pct                                                                   0.333
# ft                                                                            0
# fta                                                                           0
# ft_pct                                                                      0.0
# orb                                                                           1
# drb                                                                           4
# trb                                                                           5
# ast                                                                           2
# stl                                                                           1
# blk                                                                           0
# tov                                                                           1
# pf                                                                            0
# pts                                                                           7
# plus_minus                                                                   13
# did_not_play                                                                  0
# is_inactive                                                                   0
# ts_pct                                                                      0.5
# efg_pct                                                                     0.5
# fg3a_per_fga_pct                                                          0.429
# fta_per_fga_pct                                                             0.0
# orb_pct                                                                     5.4
# drb_pct                                                                    16.8
# trb_pct                                                                    11.8
# ast_pct                                                                     9.4
# stl_pct                                                                     2.0
# blk_pct                                                                     0.0
# tov_pct                                                                    12.5
# usg_pct                                                                    14.5
# off_rtg                                                                     106
# def_rtg                                                                     110
# bpm                                                                        -3.8
# season                                                                     2022
# minutes                                                               25.433333
# double_double                                                                 0
# triple_double                                                                 0
# DKP                                                                       18.25
# FDP                                                                        18.0
# SDP                                                                       18.75
# DKP_per_minute                                                0.717562254259502
# FDP_per_minute                                                0.707732634338139
# SDP_per_minute                                                0.737221494102228
# pf_per_minute                                                               0.0
# ts                                                                          7.0
# last_60_minutes_per_game_starting                                      29.82029
# last_60_minutes_per_game_bench                                        16.051693
# PG%                                                                         0.0
# SG%                                                                        32.0
# SF%                                                                        67.0
# PF%                                                                         0.0
# C%                                                                          0.0
# active_position_minutes                                               47.021807

# %% [markdown]
# ## First normal form

# %%
nba = nba.drop(['Inactives'], axis=1)
nba.head(3).T
# Out:
#                                                    0                  1  \
# Unnamed: 0                                         0                  1
# game_id                                 202202170BRK       202202170BRK
# game_date                                 2022-02-17         2022-02-17
# OT                                                 0                  0
# H_A                                                A                  A
# Team_Abbrev                                      WAS                WAS
# Team_Score                                       117                117
# Team_pace                                       94.5               94.5
# Team_efg_pct                                   0.627              0.627
# Team_tov_pct                                    13.5               13.5
# Team_orb_pct                                    22.9               22.9
# Team_ft_rate                                   0.157              0.157
# Team_off_rtg                                   123.8              123.8
# Opponent_Abbrev                                  BRK                BRK
# Opponent_Score                                   103                103
# Opponent_pace                                   94.5               94.5
# Opponent_efg_pct                               0.483              0.483
# Opponent_tov_pct                                13.1               13.1
# Opponent_orb_pct                                33.3               33.3
# Opponent_ft_rate                               0.191              0.191
# Opponent_off_rtg                               109.0              109.0
# player                                 Corey Kispert         Kyle Kuzma
# player_id                                  kispeco01          kuzmaky01
# starter                                            1                  1
# mp                                             32:30              30:16
# fg                                                 6                  2
# fga                                                9                  7
# fg_pct                                         0.667              0.286
# fg3                                                4                  0
# fg3a                                               6                  3
# fg3_pct                                        0.667                0.0
# ft                                                 0                  1
# fta                                                0                  1
# ft_pct                                           0.0                1.0
# orb                                                0                  0
# drb                                                1                  7
# trb                                                1                  7
# ast                                                1                  5
# stl                                                2                  1
# blk                                                0                  0
# tov                                                2                  7
# pf                                                 2                  3
# pts                                               16                  5
# plus_minus                                        13                 10
# did_not_play                                       0                  0
# is_inactive                                        0                  0
# ts_pct                                         0.889              0.336
# efg_pct                                        0.889              0.286
# fg3a_per_fga_pct                               0.667              0.429
# fta_per_fga_pct                                  0.0              0.143
# orb_pct                                          0.0                0.0
# drb_pct                                          3.3               24.7
# trb_pct                                          1.8               13.9
# ast_pct                                          4.0               18.5
# stl_pct                                          3.1                1.7
# blk_pct                                          0.0                0.0
# tov_pct                                         18.2               48.5
# usg_pct                                         15.6               22.0
# off_rtg                                          133                 55
# def_rtg                                          113                107
# bpm                                              3.1              -15.5
# season                                          2022               2022
# minutes                                         32.5          30.266667
# double_double                                      0                  0
# triple_double                                      0                  0
# DKP                                            23.75              19.75
# FDP                                             22.7               16.9
# SDP                                            24.75              17.25
# DKP_per_minute                     0.730769230769231  0.652533039647577
# FDP_per_minute                     0.698461538461538  0.558370044052863
# SDP_per_minute                     0.761538461538461  0.569933920704846
# pf_per_minute                               0.061538           0.099119
# ts                                               9.0               7.44
# last_60_minutes_per_game_starting          31.716667             34.324
# last_60_minutes_per_game_bench             22.017778          18.475954
# PG%                                              1.0                0.0
# SG%                                             36.0                0.0
# SF%                                             60.0                4.0
# PF%                                              4.0               85.0
# C%                                               0.0               11.0
# active_position_minutes                    46.253586           52.15259
#
#                                                           2
# Unnamed: 0                                                2
# game_id                                        202202170BRK
# game_date                                        2022-02-17
# OT                                                        0
# H_A                                                       A
# Team_Abbrev                                             WAS
# Team_Score                                              117
# Team_pace                                              94.5
# Team_efg_pct                                          0.627
# Team_tov_pct                                           13.5
# Team_orb_pct                                           22.9
# Team_ft_rate                                          0.157
# Team_off_rtg                                          123.8
# Opponent_Abbrev                                         BRK
# Opponent_Score                                          103
# Opponent_pace                                          94.5
# Opponent_efg_pct                                      0.483
# Opponent_tov_pct                                       13.1
# Opponent_orb_pct                                       33.3
# Opponent_ft_rate                                      0.191
# Opponent_off_rtg                                      109.0
# player                             Kentavious Caldwell-Pope
# player_id                                         caldwke01
# starter                                                   1
# mp                                                    25:26
# fg                                                        3
# fga                                                       7
# fg_pct                                                0.429
# fg3                                                       1
# fg3a                                                      3
# fg3_pct                                               0.333
# ft                                                        0
# fta                                                       0
# ft_pct                                                  0.0
# orb                                                       1
# drb                                                       4
# trb                                                       5
# ast                                                       2
# stl                                                       1
# blk                                                       0
# tov                                                       1
# pf                                                        0
# pts                                                       7
# plus_minus                                               13
# did_not_play                                              0
# is_inactive                                               0
# ts_pct                                                  0.5
# efg_pct                                                 0.5
# fg3a_per_fga_pct                                      0.429
# fta_per_fga_pct                                         0.0
# orb_pct                                                 5.4
# drb_pct                                                16.8
# trb_pct                                                11.8
# ast_pct                                                 9.4
# stl_pct                                                 2.0
# blk_pct                                                 0.0
# tov_pct                                                12.5
# usg_pct                                                14.5
# off_rtg                                                 106
# def_rtg                                                 110
# bpm                                                    -3.8
# season                                                 2022
# minutes                                           25.433333
# double_double                                             0
# triple_double                                             0
# DKP                                                   18.25
# FDP                                                    18.0
# SDP                                                   18.75
# DKP_per_minute                            0.717562254259502
# FDP_per_minute                            0.707732634338139
# SDP_per_minute                            0.737221494102228
# pf_per_minute                                           0.0
# ts                                                      7.0
# last_60_minutes_per_game_starting                  29.82029
# last_60_minutes_per_game_bench                    16.051693
# PG%                                                     0.0
# SG%                                                    32.0
# SF%                                                    67.0
# PF%                                                     0.0
# C%                                                      0.0
# active_position_minutes                           47.021807

# %% [markdown]
# ## Second normal form

# %%
players = nba[['player_id', 'player']].drop_duplicates()
players
# Out:
#         player_id                    player
# 0       kispeco01             Corey Kispert
# 1       kuzmaky01                Kyle Kuzma
# 2       caldwke01  Kentavious Caldwell-Pope
# 3        netora01                 Raul Neto
# 4       bryanth01             Thomas Bryant
# ...           ...                       ...
# 109702  frazimi01           Michael Frazier
# 110441  howarwi01            William Howard
# 110913  mbahalu01          Luc Mbah a Moute
# 111399  bowmaky01                 Ky Bowman
# 112021  pargoje01              Jeremy Pargo
#
# [812 rows x 2 columns]

# %%
nba = nba.drop(['player'], axis=1)

# %%
games = nba[['game_id', 'game_date', 'OT', 'season']].drop_duplicates()
games
# Out:
#              game_id   game_date  OT  season
# 0       202202170BRK  2022-02-17   0    2022
# 26      202202170CHO  2022-02-17   2    2022
# 48      202202170LAC  2022-02-17   0    2022
# 71      202202170MIL  2022-02-17   0    2022
# 95      202202170NOP  2022-02-17   0    2022
# ...              ...         ...  ..     ...
# 108259  202001080GSW  2020-01-08   0    2020
# 108887  202008020HOU  2020-08-02   0    2020
# 109683  201911060HOU  2019-11-06   0    2020
# 110125  201912250GSW  2019-12-25   0    2020
# 110643  202002200GSW  2020-02-20   0    2020
#
# [3197 rows x 4 columns]

# %%
nba = nba.drop(['game_date', 'OT', 'season'], axis=1)

# %%
nba.head(3).T
# Out:
#                                                    0                  1  \
# Unnamed: 0                                         0                  1
# game_id                                 202202170BRK       202202170BRK
# H_A                                                A                  A
# Team_Abbrev                                      WAS                WAS
# Team_Score                                       117                117
# Team_pace                                       94.5               94.5
# Team_efg_pct                                   0.627              0.627
# Team_tov_pct                                    13.5               13.5
# Team_orb_pct                                    22.9               22.9
# Team_ft_rate                                   0.157              0.157
# Team_off_rtg                                   123.8              123.8
# Opponent_Abbrev                                  BRK                BRK
# Opponent_Score                                   103                103
# Opponent_pace                                   94.5               94.5
# Opponent_efg_pct                               0.483              0.483
# Opponent_tov_pct                                13.1               13.1
# Opponent_orb_pct                                33.3               33.3
# Opponent_ft_rate                               0.191              0.191
# Opponent_off_rtg                               109.0              109.0
# player_id                                  kispeco01          kuzmaky01
# starter                                            1                  1
# mp                                             32:30              30:16
# fg                                                 6                  2
# fga                                                9                  7
# fg_pct                                         0.667              0.286
# fg3                                                4                  0
# fg3a                                               6                  3
# fg3_pct                                        0.667                0.0
# ft                                                 0                  1
# fta                                                0                  1
# ft_pct                                           0.0                1.0
# orb                                                0                  0
# drb                                                1                  7
# trb                                                1                  7
# ast                                                1                  5
# stl                                                2                  1
# blk                                                0                  0
# tov                                                2                  7
# pf                                                 2                  3
# pts                                               16                  5
# plus_minus                                        13                 10
# did_not_play                                       0                  0
# is_inactive                                        0                  0
# ts_pct                                         0.889              0.336
# efg_pct                                        0.889              0.286
# fg3a_per_fga_pct                               0.667              0.429
# fta_per_fga_pct                                  0.0              0.143
# orb_pct                                          0.0                0.0
# drb_pct                                          3.3               24.7
# trb_pct                                          1.8               13.9
# ast_pct                                          4.0               18.5
# stl_pct                                          3.1                1.7
# blk_pct                                          0.0                0.0
# tov_pct                                         18.2               48.5
# usg_pct                                         15.6               22.0
# off_rtg                                          133                 55
# def_rtg                                          113                107
# bpm                                              3.1              -15.5
# minutes                                         32.5          30.266667
# double_double                                      0                  0
# triple_double                                      0                  0
# DKP                                            23.75              19.75
# FDP                                             22.7               16.9
# SDP                                            24.75              17.25
# DKP_per_minute                     0.730769230769231  0.652533039647577
# FDP_per_minute                     0.698461538461538  0.558370044052863
# SDP_per_minute                     0.761538461538461  0.569933920704846
# pf_per_minute                               0.061538           0.099119
# ts                                               9.0               7.44
# last_60_minutes_per_game_starting          31.716667             34.324
# last_60_minutes_per_game_bench             22.017778          18.475954
# PG%                                              1.0                0.0
# SG%                                             36.0                0.0
# SF%                                             60.0                4.0
# PF%                                              4.0               85.0
# C%                                               0.0               11.0
# active_position_minutes                    46.253586           52.15259
#
#                                                    2
# Unnamed: 0                                         2
# game_id                                 202202170BRK
# H_A                                                A
# Team_Abbrev                                      WAS
# Team_Score                                       117
# Team_pace                                       94.5
# Team_efg_pct                                   0.627
# Team_tov_pct                                    13.5
# Team_orb_pct                                    22.9
# Team_ft_rate                                   0.157
# Team_off_rtg                                   123.8
# Opponent_Abbrev                                  BRK
# Opponent_Score                                   103
# Opponent_pace                                   94.5
# Opponent_efg_pct                               0.483
# Opponent_tov_pct                                13.1
# Opponent_orb_pct                                33.3
# Opponent_ft_rate                               0.191
# Opponent_off_rtg                               109.0
# player_id                                  caldwke01
# starter                                            1
# mp                                             25:26
# fg                                                 3
# fga                                                7
# fg_pct                                         0.429
# fg3                                                1
# fg3a                                               3
# fg3_pct                                        0.333
# ft                                                 0
# fta                                                0
# ft_pct                                           0.0
# orb                                                1
# drb                                                4
# trb                                                5
# ast                                                2
# stl                                                1
# blk                                                0
# tov                                                1
# pf                                                 0
# pts                                                7
# plus_minus                                        13
# did_not_play                                       0
# is_inactive                                        0
# ts_pct                                           0.5
# efg_pct                                          0.5
# fg3a_per_fga_pct                               0.429
# fta_per_fga_pct                                  0.0
# orb_pct                                          5.4
# drb_pct                                         16.8
# trb_pct                                         11.8
# ast_pct                                          9.4
# stl_pct                                          2.0
# blk_pct                                          0.0
# tov_pct                                         12.5
# usg_pct                                         14.5
# off_rtg                                          106
# def_rtg                                          110
# bpm                                             -3.8
# minutes                                    25.433333
# double_double                                      0
# triple_double                                      0
# DKP                                            18.25
# FDP                                             18.0
# SDP                                            18.75
# DKP_per_minute                     0.717562254259502
# FDP_per_minute                     0.707732634338139
# SDP_per_minute                     0.737221494102228
# pf_per_minute                                    0.0
# ts                                               7.0
# last_60_minutes_per_game_starting           29.82029
# last_60_minutes_per_game_bench             16.051693
# PG%                                              0.0
# SG%                                             32.0
# SF%                                             67.0
# PF%                                              0.0
# C%                                               0.0
# active_position_minutes                    47.021807

# %% [markdown]
# ## Third normal form

# %%
nba.columns
# Out:
# Index(['Unnamed: 0', 'game_id', 'H_A', 'Team_Abbrev', 'Team_Score',
#        'Team_pace', 'Team_efg_pct', 'Team_tov_pct', 'Team_orb_pct',
#        'Team_ft_rate', 'Team_off_rtg', 'Opponent_Abbrev', 'Opponent_Score',
#        'Opponent_pace', 'Opponent_efg_pct', 'Opponent_tov_pct',
#        'Opponent_orb_pct', 'Opponent_ft_rate', 'Opponent_off_rtg', 'player_id',
#        'starter', 'mp', 'fg', 'fga', 'fg_pct', 'fg3', 'fg3a', 'fg3_pct', 'ft',
#        'fta', 'ft_pct', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf',
#        'pts', 'plus_minus', 'did_not_play', 'is_inactive', 'ts_pct', 'efg_pct',
#        'fg3a_per_fga_pct', 'fta_per_fga_pct', 'orb_pct', 'drb_pct', 'trb_pct',
#        'ast_pct', 'stl_pct', 'blk_pct', 'tov_pct', 'usg_pct', 'off_rtg',
#        'def_rtg', 'bpm', 'minutes', 'double_double', 'triple_double', 'DKP',
#        'FDP', 'SDP', 'DKP_per_minute', 'FDP_per_minute', 'SDP_per_minute',
#        'pf_per_minute', 'ts', 'last_60_minutes_per_game_starting',
#        'last_60_minutes_per_game_bench', 'PG%', 'SG%', 'SF%', 'PF%', 'C%',
#        'active_position_minutes'],
#       dtype='object')

# %%
team_game = nba[['game_id', 'Team_Abbrev', 'H_A', 'Team_Score',
       'Team_pace', 'Team_efg_pct', 'Team_tov_pct', 'Team_orb_pct',
       'Team_ft_rate', 'Team_off_rtg', 'Opponent_Abbrev']].drop_duplicates()

# %%
team_game.head(4).T
# Out:
#                            0             13            26            37
# game_id          202202170BRK  202202170BRK  202202170CHO  202202170CHO
# Team_Abbrev               WAS           BRK           MIA           CHO
# H_A                         A             H             A             H
# Team_Score                117           103           111           107
# Team_pace                94.5          94.5          88.8          88.8
# Team_efg_pct            0.627         0.483         0.471         0.453
# Team_tov_pct             13.5          13.1          11.1          13.6
# Team_orb_pct             22.9          33.3          26.8          28.1
# Team_ft_rate            0.157         0.191         0.147         0.221
# Team_off_rtg            123.8         109.0         103.4          99.7
# Opponent_Abbrev           BRK           WAS           CHO           MIA

# %%
player_game = nba.drop(['Unnamed: 0', 'H_A', 'Team_Abbrev', 'Team_Score',
       'Team_pace', 'Team_efg_pct', 'Team_tov_pct', 'Team_orb_pct',
       'Team_ft_rate', 'Team_off_rtg', 'Opponent_Abbrev', 'Opponent_Score',
       'Opponent_pace', 'Opponent_efg_pct', 'Opponent_tov_pct',
       'Opponent_orb_pct', 'Opponent_ft_rate', 'Opponent_off_rtg'],
                      axis=1)

# %%
team_game
# Out:
#              game_id Team_Abbrev H_A  Team_Score  Team_pace  Team_efg_pct  \
# 0       202202170BRK         WAS   A         117       94.5         0.627
# 13      202202170BRK         BRK   H         103       94.5         0.483
# 26      202202170CHO         MIA   A         111       88.8         0.471
# 37      202202170CHO         CHO   H         107       88.8         0.453
# 48      202202170LAC         HOU   A         111      103.7         0.533
# ...              ...         ...  ..         ...        ...           ...
# 112068  202002270GSW         GSW   H          86      104.8         0.481
# 112079  202002290PHO         GSW   A         115       98.6         0.523
# 112090  202003010GSW         GSW   H         110      100.2         0.522
# 112101  202003030DEN         GSW   A         116       94.4         0.622
# 112112  202003070GSW         GSW   H         118       90.9         0.606
#
#         Team_tov_pct  Team_orb_pct  Team_ft_rate  Team_off_rtg Opponent_Abbrev
# 0               13.5          22.9         0.157         123.8             BRK
# 13              13.1          33.3         0.191         109.0             WAS
# 26              11.1          26.8         0.147         103.4             CHO
# 37              13.6          28.1         0.221          99.7             MIA
# 48              15.3          24.0         0.154         107.1             LAC
# ...              ...           ...           ...           ...             ...
# 112068          23.6          12.2         0.113          82.1             LAL
# 112079           9.0          28.9         0.276         116.6             PHO
# 112090          17.4          38.3         0.191         109.8             WAS
# 112101          10.7          12.8         0.171         122.9             DEN
# 112112           7.0          18.9         0.263         129.9             PHI
#
# [6394 rows x 11 columns]

# %%
player_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112123 entries, 0 to 112122
# Data columns (total 59 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   game_id                            112123 non-null  object
#  1   player_id                          112123 non-null  object
#  2   starter                            112123 non-null  int64
#  3   mp                                 112123 non-null  object
#  4   fg                                 112123 non-null  int64
#  5   fga                                112123 non-null  int64
#  6   fg_pct                             112123 non-null  float64
#  7   fg3                                112123 non-null  int64
#  8   fg3a                               112123 non-null  int64
#  9   fg3_pct                            112123 non-null  float64
#  10  ft                                 112123 non-null  int64
#  11  fta                                112123 non-null  int64
#  12  ft_pct                             112123 non-null  float64
#  13  orb                                112123 non-null  int64
#  14  drb                                112123 non-null  int64
#  15  trb                                112123 non-null  int64
#  16  ast                                112123 non-null  int64
#  17  stl                                112123 non-null  int64
#  18  blk                                112123 non-null  int64
#  19  tov                                112123 non-null  int64
#  20  pf                                 112123 non-null  int64
#  21  pts                                112123 non-null  int64
#  22  plus_minus                         112123 non-null  int64
#  23  did_not_play                       112123 non-null  int64
#  24  is_inactive                        112123 non-null  int64
#  25  ts_pct                             112123 non-null  float64
#  26  efg_pct                            112123 non-null  float64
#  27  fg3a_per_fga_pct                   112123 non-null  float64
#  28  fta_per_fga_pct                    112123 non-null  float64
#  29  orb_pct                            112123 non-null  float64
#  30  drb_pct                            112123 non-null  float64
#  31  trb_pct                            112123 non-null  float64
#  32  ast_pct                            112123 non-null  float64
#  33  stl_pct                            112123 non-null  float64
#  34  blk_pct                            112123 non-null  float64
#  35  tov_pct                            112123 non-null  float64
#  36  usg_pct                            112123 non-null  float64
#  37  off_rtg                            112123 non-null  int64
#  38  def_rtg                            112123 non-null  int64
#  39  bpm                                112123 non-null  float64
#  40  minutes                            112123 non-null  float64
#  41  double_double                      112123 non-null  int64
#  42  triple_double                      112123 non-null  int64
#  43  DKP                                112123 non-null  float64
#  44  FDP                                112123 non-null  float64
#  45  SDP                                112123 non-null  float64
#  46  DKP_per_minute                     92725 non-null   object
#  47  FDP_per_minute                     92725 non-null   object
#  48  SDP_per_minute                     92725 non-null   object
#  49  pf_per_minute                      92724 non-null   float64
#  50  ts                                 112123 non-null  float64
#  51  last_60_minutes_per_game_starting  109403 non-null  float64
#  52  last_60_minutes_per_game_bench     109403 non-null  float64
#  53  PG%                                111976 non-null  float64
#  54  SG%                                111976 non-null  float64
#  55  SF%                                111976 non-null  float64
#  56  PF%                                111976 non-null  float64
#  57  C%                                 111976 non-null  float64
#  58  active_position_minutes            97003 non-null   float64
# dtypes: float64(30), int64(23), object(6)
# memory usage: 50.5+ MB

# %%
team_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6394 entries, 0 to 112112
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   game_id          6394 non-null   object
#  1   Team_Abbrev      6394 non-null   object
#  2   H_A              6394 non-null   object
#  3   Team_Score       6394 non-null   int64
#  4   Team_pace        6394 non-null   float64
#  5   Team_efg_pct     6394 non-null   float64
#  6   Team_tov_pct     6394 non-null   float64
#  7   Team_orb_pct     6394 non-null   float64
#  8   Team_ft_rate     6394 non-null   float64
#  9   Team_off_rtg     6394 non-null   float64
#  10  Opponent_Abbrev  6394 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 599.4+ KB

# %%
# Out:
#              game_id Team_Abbrev H_A  Team_Score  Team_pace  Team_efg_pct  \
# 0       202202170BRK         WAS   A         117       94.5         0.627
# 13      202202170BRK         BRK   H         103       94.5         0.483
# 26      202202170CHO         MIA   A         111       88.8         0.471
# 37      202202170CHO         CHO   H         107       88.8         0.453
# 48      202202170LAC         HOU   A         111      103.7         0.533
# ...              ...         ...  ..         ...        ...           ...
# 112068  202002270GSW         GSW   H          86      104.8         0.481
# 112079  202002290PHO         GSW   A         115       98.6         0.523
# 112090  202003010GSW         GSW   H         110      100.2         0.522
# 112101  202003030DEN         GSW   A         116       94.4         0.622
# 112112  202003070GSW         GSW   H         118       90.9         0.606
#
#         Team_tov_pct  Team_orb_pct  Team_ft_rate  Team_off_rtg Opponent_Abbrev
# 0               13.5          22.9         0.157         123.8             BRK
# 13              13.1          33.3         0.191         109.0             WAS
# 26              11.1          26.8         0.147         103.4             CHO
# 37              13.6          28.1         0.221          99.7             MIA
# 48              15.3          24.0         0.154         107.1             LAC
# ...              ...           ...           ...           ...             ...
# 112068          23.6          12.2         0.113          82.1             LAL
# 112079           9.0          28.9         0.276         116.6             PHO
# 112090          17.4          38.3         0.191         109.8             WAS
# 112101          10.7          12.8         0.171         122.9             DEN
# 112112           7.0          18.9         0.263         129.9             PHI
#
# [6394 rows x 11 columns]

# %%
dbserver = psycopg2.connect(
    user = 'postgres',
    password = POSTGRES_PASSWORD,
    host = 'postgres',
    port = '5432'
)
dbserver.autocommit = True

# %%
cursor = dbserver.cursor()

# %%
try:
    cursor.execute('CREATE DATABASE nba')
except:
    cursor.execute('DROP DATABASE nba')
    cursor.execute('CREATE DATABASE nba')

# %%
engine = create_engine("postgresql+psycopg2://{user}:{pw}@{service}/{db}".format(
    user = 'postgres',
    pw = POSTGRES_PASSWORD,
    service = 'postgres',
    db = 'nba'
))

# %%
games.columns = [x.lower() for x in games.columns]
players.columns = [x.lower() for x in players.columns]
team_game.columns = [x.lower() for x in team_game.columns]
player_game.columns = [x.lower() for x in player_game.columns]

# %%
games.to_sql('games', con=engine, index=False, chunksize=1000, if_exists='replace')
# Out:
# 3197

# %%
players.to_sql('players', con=engine, index=False, chunksize=1000, if_exists='replace')
# Out:
# 812

# %%
team_game.to_sql('team_game', con=engine, index=False, chunksize=1000, if_exists='replace')
# Out:
# 6394

# %%
player_game.to_sql('player_game', con=engine, index=False, chunksize=500, if_exists='replace')
# Out:
# 112123

# %%
myquery = '''
SELECT *
FROM games
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#            game_id   game_date  ot  season
# 0     202202170BRK  2022-02-17   0    2022
# 1     202202170CHO  2022-02-17   2    2022
# 2     202202170LAC  2022-02-17   0    2022
# 3     202202170MIL  2022-02-17   0    2022
# 4     202202170NOP  2022-02-17   0    2022
# ...            ...         ...  ..     ...
# 3192  202001080GSW  2020-01-08   0    2020
# 3193  202008020HOU  2020-08-02   0    2020
# 3194  201911060HOU  2019-11-06   0    2020
# 3195  201912250GSW  2019-12-25   0    2020
# 3196  202002200GSW  2020-02-20   0    2020
#
# [3197 rows x 4 columns]

# %%
myquery = '''
SELECT *
FROM games
WHERE game_date = '2021-04-12'
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#         game_id   game_date  OT  season
# 0  202104120GSW  2021-04-12   0    2021
# 1  202104120NYK  2021-04-12   0    2021
# 2  202104120ORL  2021-04-12   0    2021
# 3  202104120UTA  2021-04-12   0    2021
# 4  202104120DAL  2021-04-12   0    2021
# 5  202104120NOP  2021-04-12   0    2021
# 6  202104120MEM  2021-04-12   0    2021
# 7  202104120PHO  2021-04-12   0    2021

# %%
player_game
# Out:
#              game_id  player_id  starter        mp  fg  fga  fg_pct  fg3  \
# 0       202202170BRK  kispeco01        1     32:30   6    9   0.667    4
# 1       202202170BRK  kuzmaky01        1     30:16   2    7   0.286    0
# 2       202202170BRK  caldwke01        1     25:26   3    7   0.429    1
# 3       202202170BRK   netora01        1     20:40   5    7   0.714    1
# 4       202202170BRK  bryanth01        1     14:04   5    6   0.833    0
# ...              ...        ...      ...       ...  ..  ...     ...  ...
# 112118  202003070GSW  wiggian01        1  37:04:00   3   10   0.300    0
# 112119  202003070GSW  toscaju01        1  27:43:00   3    6   0.500    0
# 112120  202003070GSW  bendedr01        0     13:15   4    4   1.000    2
# 112121  202003070GSW  muldemy01        1  31:48:00   5   10   0.500    3
# 112122  202003070GSW  randlch01        0     13:36   0    1   0.000    0
#
#         fg3a  fg3_pct  ...  pf_per_minute     ts  \
# 0          6    0.667  ...       0.061538   9.00
# 1          3    0.000  ...       0.099119   7.44
# 2          3    0.333  ...       0.000000   7.00
# 3          1    1.000  ...       0.048387   7.88
# 4          1    0.000  ...       0.000000   6.88
# ...      ...      ...  ...            ...    ...
# 112118     0    0.000  ...       0.107914  13.08
# 112119     2    0.000  ...       0.036079   6.00
# 112120     2    1.000  ...       0.150943   4.00
# 112121     7    0.429  ...       0.094340  12.64
# 112122     0    0.000  ...       0.000000   2.76
#
#         last_60_minutes_per_game_starting  last_60_minutes_per_game_bench  \
# 0                               31.716667                       22.017778
# 1                               34.324000                       18.475954
# 2                               29.820290                       16.051693
# 3                               29.920833                       14.603922
# 4                               20.095833                       14.538095
# ...                                   ...                             ...
# 112118                          33.110667                       19.232562
# 112119                          25.470833                       20.228571
# 112120                          24.083333                       13.228788
# 112121                          34.783333                       27.691667
# 112122                          10.415645                        6.050000
#
#          PG%   SG%   SF%   PF%     C%  active_position_minutes
# 0        1.0  36.0  60.0   4.0    0.0                46.253586
# 1        0.0   0.0   4.0  85.0   11.0                52.152590
# 2        0.0  32.0  67.0   0.0    0.0                47.021807
# 3       90.0  10.0   0.0   0.0    0.0                27.603314
# 4        0.0   0.0   0.0   0.0  100.0                36.472537
# ...      ...   ...   ...   ...    ...                      ...
# 112118   0.0   2.0  77.0  21.0    0.0                57.207786
# 112119   5.0  45.0  43.0   7.0    0.0                58.202391
# 112120   0.0   0.0   0.0   9.0   91.0                49.630640
# 112121   0.0  44.0  48.0   8.0    0.0                58.923515
# 112122  81.0  19.0   0.0   0.0    0.0                45.958787
#
# [112123 rows x 59 columns]

# %%
# all games where a player scores > 40, and team > 120, and calculate % of team scores

# %%
myquery = '''
SELECT pg.game_id, pg.player_id, pg.pts, tg.team_score,
    point_percent = pg.pts/tg.team_score 
FROM player_game pg
INNER JOIN team_game tg
    ON pg.game_id = tg.game_id
WHERE pg.pts > 40 AND tg.team_score > 120
'''
pd.read_sql_query(myquery, con=engine)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# UndefinedColumn: column "point_percent" does not exist
# LINE 3:     point_percent = pg.pts/tg.team_score
#             ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[63], line 9
#       1 myquery = '''
#       2 SELECT pg.game_id, pg.player_id, pg.pts, tg.team_score,
#       3     point_percent = pg.pts/tg.team_score
#    (...)
#       7 WHERE pg.pts > 40 AND tg.team_score > 120
#       8 '''
# ----> 9 pd.read_sql_query(myquery, con=engine)
#
# File /usr/local/lib/python3.11/site-packages/pandas/io/sql.py:469, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     466     dtype_backend = "numpy"  # type: ignore[assignment]
#     468 with pandasSQL_builder(con) as pandas_sql:
# --> 469     return pandas_sql.read_query(
#     470         sql,
#     471         index_col=index_col,
#     472         params=params,
#     473         coerce_float=coerce_float,
#     474         parse_dates=parse_dates,
#     475         chunksize=chunksize,
#     476         dtype=dtype,
#     477         dtype_backend=dtype_backend,
#     478     )
#
# File /usr/local/lib/python3.11/site-packages/pandas/io/sql.py:1738, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1681 def read_query(
#    1682     self,
#    1683     sql: str,
#    (...)
#    1690     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1691 ) -> DataFrame | Iterator[DataFrame]:
#    1692     """
#    1693     Read SQL query into a DataFrame.
#    1694
#    (...)
#    1736
#    1737     """
# -> 1738     result = self.execute(sql, params)
#    1739     columns = result.keys()
#    1741     if chunksize is not None:
#
# File /usr/local/lib/python3.11/site-packages/pandas/io/sql.py:1562, in SQLDatabase.execute(self, sql, params)
#    1560 args = [] if params is None else [params]
#    1561 if isinstance(sql, str):
# -> 1562     return self.con.exec_driver_sql(sql, *args)
#    1563 return self.con.execute(sql, *args)
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1778, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1773 execution_options = self._execution_options.merge_with(
#    1774     execution_options
#    1775 )
#    1777 dialect = self.dialect
# -> 1778 ret = self._execute_context(
#    1779     dialect,
#    1780     dialect.execution_ctx_cls._init_statement,
#    1781     statement,
#    1782     None,
#    1783     execution_options,
#    1784     statement,
#    1785     distilled_parameters,
#    1786 )
#    1788 return ret
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2343, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2341 elif should_wrap:
#    2342     assert sqlalchemy_exception is not None
# -> 2343     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2344 else:
#    2345     assert exc_info[1] is not None
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)
#    1980         context.executemany,
#    1981     )
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "point_percent" does not exist
# LINE 3:     point_percent = pg.pts/tg.team_score
#             ^
#
# [SQL:
# SELECT pg.game_id, pg.player_id, pg.pts, tg.team_score,
#     point_percent = pg.pts/tg.team_score
# FROM player_game pg
# INNER JOIN team_game tg
#     ON pg.game_id = tg.game_id
# WHERE pg.pts > 40 AND tg.team_score > 120
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)
